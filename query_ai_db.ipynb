# %%
# Install missing Gemini package if not installed
import sys
# !{sys.executable} -m pip install google-generativeai --quiet

import pandas as pd
import psycopg2
from dotenv import load_dotenv
import google.generativeai as genai
from utils import get_db_url
from sqlalchemy import create_engine
import re

load_dotenv()

# Configure Gemini API Key from .streamlit/secrets.toml or .env
import streamlit as st
try:
    OPENAI_API_KEY = st.secrets["OPENAI_API_KEY"]
except:
    import os
    OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

genai.configure(api_key=OPENAI_API_KEY)

print("Setup complete 🟢")

# %%
# SQL database engine
db_url = get_db_url()
engine = create_engine(db_url)

def run_sql(sql):
    try:
        df = pd.read_sql(sql, engine)
        return df
    except Exception as e:
        print("SQL Error:", e)

# %%
DATABASE_URL="postgres://user:pass@host:port/dbname"

# %%
load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")

if not DATABASE_URL:
    raise ValueError("DATABASE_URL not found in .env")

DATABASE_URL

# %%
def run_query(query):
    try:
        conn = psycopg2.connect(DATABASE_URL)
        df = pd.read_sql(query, conn)
        conn.close()
        return df
    except Exception as e:
        print("Error executing query:", e)

# %%
query = """
SELECT country.country AS country, COUNT(*) AS total_customers
FROM customer
JOIN country ON customer.countryid = country.countryid
GROUP BY country.country
ORDER BY total_customers DESC;
"""
run_query(query)
